# %% [markdown]
# # Salmonella homologues
#
# 10/11/2025
#
# Since the last notebook, little work involving running local software has been done. Much of the work since then has been via online tools such as BLASTp and AlphaFold
#
# ## BLASTp
#
# In the literature, EspY3 has been identified to contain a domain homologous to the Salmonella PipB2 protein. My queries in BLAST had not returned any Salmonella hits matching the literature, so I decided to a) query the specific PipB2 domain annotated in literature and b) query EspY3 against only Salmonella spp.
#
# ### BLASTp of the PipB2 domain and Salmonella spp.
#
# I  queried the full length EspY3 against refseq_protein database but limited the search to Salmonella cholorea-suis (taxid:278901). This yielded 105 Salmonella hits - 91 salmonella enterica and 14 multispecies salmonella.
#
# Below I will allign the hits with the previous EspY3 MSA as the seed.
#
# In Jalview, I created two groups: the seed sequences and the salmonella protein sequences.
#
# TODO:
# - Figure out how to map conservation onto EspY3
# - In Jalview and/or structure
# - Map conserved residues onto structure? Compare to PipB2 structure. Is the structure conserved? Could this be an indication of function? What are PipB2 interactions?

# %%
# !mafft --add ../../pipb2_wd/salmonella_seqdump.fasta --keeplength --reorder ../../data/cleaned/trimal/espy3-50.mafft.trimal.fasta > ../../pipb2_wd/espy3seed_salmonella.mafft.fasta
# Out:
# nadd = 105
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8176 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   101 / 149
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   140 / 149
# done.
#
# Progressive alignment 1/2...
# STEP   148 / 148
# done.
#
# Making a distance matrix from msa..
#   100 / 149
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   140 / 149
# done.
#
# Progressive alignment 2/2...
# STEP   148 / 148
# done.
#
# disttbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# To keep the alignment length, 43 letters were DELETED.
# To know the positions of deleted letters, rerun the same command with the --mapout option.
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# ...
