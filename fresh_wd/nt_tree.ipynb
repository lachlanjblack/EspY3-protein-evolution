# %% [markdown]
# # Making a phylogenetic tree from back-traced nucleotide sequences
#
# Using a proteins nucleotide sequence over amino acid for construction of a phylogenetic tree has a number of advantages.
#
# As each codon has 3 nucleotides per amino acid, this creates a longer allignment with more phylogenetic signal for tree-building algorithms which improves resolution, especially for recent divergence.
#
# Nucleotide sequences also capture synonymous mutations (those which don't change the amino acid), which provides additional evolutionary information that AA sequences do not. This is useful for studying closely-related proteins which we have here.
#
# This approach is also better for recent evolutionary timescales because NTs utate faster and accumulate changes more quickly. Thuis will be helpful for resolving relationships between the closely related E. coli and Shigella proteins.
#
# ## 1. Using `ncfp` to back-trace nucleotide sequences
#
# `ncfp` is a tool that takes amino acid sequences as an input, and uses these to obtain corresponsing nucleotide sequences.

# %%
# !ncfp protein_tree/mafft/alligned.fasta \
    nt_tree/msa_ncfp \
    lachlanjblack@gmail.com
# Out:
# Process input sequences: 100%|█████████████████| 92/92 [00:00<00:00, 526.56it/s]
# Search NT IDs:   0%|                                     | 0/92 [00:04<?, ?it/s]
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/proj313/bin/ncfp", line 10, in <module>
#     sys.exit(run_main())
#              ~~~~~~~~^^
#   File "/opt/anaconda3/envs/proj313/lib/python3.13/site-packages/ncbi_cds_from_protein/scripts/ncfp.py", line 261, in run_main
#     addedrows, countfail = search_nt_ids(
#                            ~~~~~~~~~~~~~^
#         qrecords, cachepath, args.retries, disabletqdm=args.disabletqdm
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/anaconda3/envs/proj313/lib/python3.13/site-packages/ncbi_cds_from_protein/entrez.py", line 237, in search_nt_ids
#     result = elink_fetch_with_retries(
#         record.id, "protein", "protein_nuccore", retries
#     )
#   File "/opt/anaconda3/envs/proj313/lib/python3.13/site-packages/ncbi_cds_from_protein/entrez.py", line 318, in elink_fetch_with_retries
#     raise NCFPMaxretryException(
#         "Query ID %s ELink failed\n%s" % (query_id, last_exception())
#     )
# ncbi_cds_from_protein.entrez.NCFPMaxretryException: Query ID EPD1771162.1 ELink failed
# NoneType: None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined
