# %% [markdown]
# # Escherichia albertii
#
# Blast search exluding E. coli reveals homologues in E. albertii
#
# AlphaFold prediction appears similar structure
#
# todo:
# - Download and allign hits
# - Compare structure to E. coli EspY3
# - Figure out what to do with information on Salmonella homologues
# - Map conservation onto structures

# %% [markdown]
# # Creating an MSA of *E. albertii* BLAST hits
#
# I queried BLASTp with the *E. coli* EspY3 protein, and limited the search to *E. albertii* in the refseq_protein database and got 89 hits.
#
# Here I will allign the sequences which I will use to map conservation onto the structure.

# %%
# !mafft --maxiterate 1000 --localpair ../../albertii_wd/albertii_seqdump.fasta > ../../albertii_wd/albertii.mafft.fasta
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    80 / 89
# done.
#
# Progressive alignment ...
# STEP    88 /88
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    80 / 89
# Segment   1/  1    1- 535
# STEP 002-002-0  identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.526
# ...

# %% [markdown]
# I manually removed a number of truncated sequences which resulted in a clean, highly-conserved set of sequences that I will use for mapping conservation on the 3D structure
