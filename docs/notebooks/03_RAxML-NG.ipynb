# %% [markdown]
# # RAxML-NG on 50% ID MSA
#
# Aim: Use RAxML-NG to generate a phylogenetic tree for my protein.
# This notebook documents the process I used:
# 1. Building the Maximum-liklhood (ML) tree
# 2. Generating bootstrap replicates
# 3. Mapping bootsrap support onto the ML tree

# %%
from pathlib import Path # allows handling of files and folder paths cleanly
import subprocess # allows terminal commands to be run from python

# PARAMETERS
MSA = Path("../../data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta") # trimmed MSA
OUTDIR = Path("../../data/cleaned/raxml/test/01_50id_bootstrap") # output folder for RaxML results
PREFIX = "mytree" # label to prefix all the output files
MODEL = "Blosum62+G4" # substitution model used for protein data
BS_TREES = 100 # number of bootstrap replicates
THREADS = "auto" # use all available CPU threads automatically

# Make sure output folder exists
OUTDIR.mkdir(parents=True, exist_ok=True)

# Print settings to confirm they are correct
print (f"MSA: {MSA.resolve()}")
print(f"OUTDIR: {OUTDIR.resolve()}")
print(f"MODEL: {MODEL}")
# Out:
# MSA: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta
# OUTDIR: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap
# MODEL: Blosum62+G4

# %%
# Define small helper function to run terminal commands
def run(cmd):
    print(f"\n$ {cmd}\n") # prints command to show exactly whas ran
    process = subprocess.run(cmd, shell=True) # runs command in terminal
    if process.returncode != 0: # checks if it failed (non-zero = error)
        raise RuntimeError(f"Command failed: {cmd}") # stop notebook if it failed

# %% [markdown]
# Explanation of the RAxML-NG command:
# - `--search` -> perform a maximum-likelihood search
# - `--msa` -> the MSA file used to make tree
# - `--model` -> the substitution model (Blosum62+G4)
# - `--prefix` -> sets output file prefix
# - `--threads auto` -> use all CPU cores

# %%
# Build the ML tree

# Outputs:
    # {PREFIX}.raxml.bestTREE -> Best ML tree
    # {PREFIX}.raxml.log -> Log file
    # {PREFIX}.raxml.mlTrees -> ML search trees
run(f"raxml-ng --search --msa {MSA} --model {MODEL} --prefix {OUTDIR / PREFIX} --threads {THREADS}")
# Out:
# $ raxml-ng --search --msa ../../data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta --model Blosum62+G4 --prefix ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree --threads auto
#
#
# RAxML-NG v. 1.2.2 released on 30.04.2024 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth, Julia Haag, Anastasis Togkousidis.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M2, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 02-Nov-2025 12:06:16 as follows:
#
# raxml-ng --search --msa ../../data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta --model Blosum62+G4 --prefix ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree --threads auto
#
# Analysis options:
#   run mode: ML tree search
#   start tree(s): random (10) + parsimony (10)
#   random seed: 1762085176
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   logLH epsilon: general: 10.000000, brlen-triplet: 1000.000000
#   fast spr radius: AUTO
#   spr subtree cutoff: 1.000000
#   fast CLV updates: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# [00:00:00] Reading alignment from file: ../../data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta
# [00:00:00] Loaded alignment with 44 taxa and 524 sites
#
# WARNING: Sequences tr|A0A0D8WGH1|A0A0D8WGH1_ECOLX/1-523 and tr|A0A377DGX1|A0A377DGX1_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A1Q5ZEH3|A0A1Q5ZEH3_ECOLX/1-523 and tr|A0A3R8KSB7|A0A3R8KSB7_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0AAW5Z1M4|A0AAW5Z1M4_ECOLX/1-523 and tr|A0AAW6W494|A0AAW6W494_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|W1X2U4|W1X2U4_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0A376VQ42|A0A376VQ42_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|W1XNK9|W1XNK9_9ZZZZ/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0A6D1PLN0|A0A6D1PLN0_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0A8S7N1T2|A0A8S7N1T2_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0AAW5ZB89|A0AAW5ZB89_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|W1YEN7|W1YEN7_9ZZZZ/1-523 and tr|A0A0H3PZQ4|A0A0H3PZQ4_ECO5C/1-523 are exactly identical!
# WARNING: Sequences tr|A0A767FIQ4|A0A767FIQ4_ECOLX/1-520 and tr|A0A793GC28|A0A793GC28_ECOLX/1-520 are exactly identical!
# WARNING: Sequences tr|A0A767FIQ4|A0A767FIQ4_ECOLX/1-520 and tr|A0A9P2PS47|A0A9P2PS47_ECOLX/1-520 are exactly identical!
# WARNING: Sequences tr|A0A767FIQ4|A0A767FIQ4_ECOLX/1-520 and tr|A0A9Q6ZFC8|A0A9Q6ZFC8_ECO57/1-520 are exactly identical!
# WARNING: Sequences tr|Q8XE85|Q8XE85_ECO57/1-518 and tr|A0A793GH32|A0A793GH32_ECOLX/1-518 are exactly identical!
# WARNING: Duplicate sequences found: 14
#
# NOTE: Reduced alignment (with duplicates and gap-only sites/taxa removed)
# NOTE: was saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.reduced.phy
#
# Alignment comprises 1 partitions and 185 patterns
#
# Partition 0: noname
# Model: BLOSUM62+G4m
# Alignment sites / patterns: 524 / 185
# Gaps: 0.61 %
# Invariant sites: 71.37 %
#
#
# NOTE: Binary MSA file created: ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.rba
#
# Parallelization scheme autoconfig: 8 worker(s) x 1 thread(s)
#
# [00:00:00] Generating 10 random starting tree(s) with 44 taxa
# [00:00:00] Generating 10 parsimony starting tree(s) with 44 taxa
# Parallel parsimony with 8 threads
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 185 / 14800
# [00:00:00] Data distribution: max. searches per worker: 3
#
# Starting ML tree search with 20 distinct starting trees
#
# [00:00:00 -8122.682599] Initial branch length optimization
# [00:00:00 -6949.356372] Model parameter optimization (eps = 10.000000)
# [00:00:00 -6395.480220] AUTODETECT spr round 1 (radius: 5)
# [00:00:01 -4152.043801] AUTODETECT spr round 2 (radius: 10)
# [00:00:03 -3405.691629] AUTODETECT spr round 3 (radius: 15)
# [00:00:04 -3404.798195] AUTODETECT spr round 4 (radius: 20)
# [00:00:04 -3403.883119] AUTODETECT spr round 5 (radius: 25)
# [00:00:04 -3402.000191] SPR radius for FAST iterations: 25 (autodetect)
# [00:00:04 -3402.000191] Model parameter optimization (eps = 3.000000)
# [00:00:05 -3256.420902] FAST spr round 1 (radius: 25)
# [00:00:06 -3202.580729] FAST spr round 2 (radius: 25)
# [00:00:07 -3202.580720] Model parameter optimization (eps = 1.000000)
# [00:00:07 -3202.517019] SLOW spr round 1 (radius: 5)
# [00:00:10 -3202.045651] SLOW spr round 2 (radius: 10)
# [00:00:12 -3202.045568] SLOW spr round 3 (radius: 15)
# [00:00:13 -3202.045568] SLOW spr round 4 (radius: 20)
# [00:00:14] [worker #2] ML tree search #3, logLikelihood: -3202.045417
# [00:00:14 -3202.045568] SLOW spr round 5 (radius: 25)
# [00:00:14] [worker #4] ML tree search #5, logLikelihood: -3207.155663
# [00:00:14 -3202.045568] Model parameter optimization (eps = 0.100000)
#
# [00:00:14] [worker #0] ML tree search #1, logLikelihood: -3202.045419
#
# [00:00:14 -7818.380660] Initial branch length optimization
# [00:00:14] [worker #7] ML tree search #8, logLikelihood: -3202.047978
# [00:00:14 -6641.492603] Model parameter optimization (eps = 10.000000)
# [00:00:15 -6131.472300] AUTODETECT spr round 1 (radius: 5)
# [00:00:15] [worker #6] ML tree search #7, logLikelihood: -3203.258592
# [00:00:16] [worker #5] ML tree search #6, logLikelihood: -3200.654328
# [00:00:16] [worker #1] ML tree search #2, logLikelihood: -3201.273956
# [00:00:16 -3907.993547] AUTODETECT spr round 2 (radius: 10)
# [00:00:16] [worker #3] ML tree search #4, logLikelihood: -3201.143356
# [00:00:18 -3414.741249] AUTODETECT spr round 3 (radius: 15)
# [00:00:19 -3412.693466] AUTODETECT spr round 4 (radius: 20)
# [00:00:19 -3409.732941] AUTODETECT spr round 5 (radius: 25)
# [00:00:19 -3400.292674] SPR radius for FAST iterations: 25 (autodetect)
# [00:00:19 -3400.292674] Model parameter optimization (eps = 3.000000)
# [00:00:19 -3265.191665] FAST spr round 1 (radius: 25)
# [00:00:21 -3202.208667] FAST spr round 2 (radius: 25)
# [00:00:22 -3202.208608] Model parameter optimization (eps = 1.000000)
# [00:00:22 -3202.049015] SLOW spr round 1 (radius: 5)
# [00:00:24] [worker #4] ML tree search #13, logLikelihood: -3203.258912
# [00:00:24 -3202.048369] SLOW spr round 2 (radius: 10)
# [00:00:24] [worker #2] ML tree search #11, logLikelihood: -3202.047982
# [00:00:26] [worker #7] ML tree search #16, logLikelihood: -3202.047980
# [00:00:26] [worker #5] ML tree search #14, logLikelihood: -3204.197293
# [00:00:26] [worker #6] ML tree search #15, logLikelihood: -3200.654334
# [00:00:27 -3202.048369] SLOW spr round 3 (radius: 15)
# [00:00:28 -3202.048369] SLOW spr round 4 (radius: 20)
# [00:00:28] [worker #3] ML tree search #12, logLikelihood: -3200.654366
# [00:00:28 -3202.048369] SLOW spr round 5 (radius: 25)
# [00:00:28 -3202.048369] Model parameter optimization (eps = 0.100000)
#
# [00:00:29] [worker #0] ML tree search #9, logLikelihood: -3202.048102
#
# [00:00:29 -4434.663881] Initial branch length optimization
# [00:00:29 -3223.902327] Model parameter optimization (eps = 10.000000)
# [00:00:29 -3210.381495] AUTODETECT spr round 1 (radius: 5)
 0.388355 0.357544 1.179091 0.341986 0.674617 8.311839 0.445570 6.030559 2.064840 0.374556 0.352969 0.915260 0.691475 0.811246 2.231406 1.073061 0.266925 1.047383 1.752166 1.303875 0.332243 0.717993 0.498138 1.773855 0.454124 0.918723 1.488548 0.888101 0.951682 2.575851 0.233598 0.540028 0.488206 2.074325 6.747260 0.838120 1.169130 1.005452 0.252215 0.369405 0.496908 5.151556 0.387926 0.796752 0.561925 0.513128 0.801010 2.253074 4.054419 0.266509 1.000000
#
#
# Final LogLikelihood: -3200.654328
#
# AIC score: 6573.308656 / AICc score: 6607.551219 / BIC score: 6939.796941
# Free parameters (model + branch lengths): 86
#
# WARNING: Best ML tree contains 18 near-zero branches!
#
# Best ML tree with collapsed near-zero branches saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.bestTreeCollapsed
# Best ML tree saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.bestTree
# All ML trees saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.mlTrees
# Optimized model saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.bestModel
#
# Execution log saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.log
#
# Analysis started: 02-Nov-2025 12:06:16 / finished: 02-Nov-2025 12:06:58
#
# Elapsed time: 41.485 seconds

# %%
# Generate bootstraps

# Output: {PREFIX}_bs.raxml.bootstraps
run(f"raxml-ng --bootstrap --msa {MSA} --model {MODEL} --bs-trees {BS_TREES} --prefix {OUTDIR / (PREFIX + '_bs')} --threads {THREADS}")
# Out:
# $ raxml-ng --bootstrap --msa ../../data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta --model Blosum62+G4 --bs-trees 100 --prefix ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs --threads auto
#
#
# RAxML-NG v. 1.2.2 released on 30.04.2024 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth, Julia Haag, Anastasis Togkousidis.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M2, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 02-Nov-2025 12:12:03 as follows:
#
# raxml-ng --bootstrap --msa ../../data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta --model Blosum62+G4 --bs-trees 100 --prefix ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs --threads auto
#
# Analysis options:
#   run mode: Bootstrapping
#   start tree(s):
#   bootstrap replicates: parsimony (100)
#   random seed: 1762085523
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   logLH epsilon: general: 0.100000, brlen-triplet: 1000.000000
#   fast spr radius: AUTO
#   spr subtree cutoff: 1.000000
#   fast CLV updates: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# [00:00:00] Reading alignment from file: ../../data/cleaned/trimal/espy3-50.mafft.r07s08.trim.fasta
# [00:00:00] Loaded alignment with 44 taxa and 524 sites
#
# WARNING: Sequences tr|A0A0D8WGH1|A0A0D8WGH1_ECOLX/1-523 and tr|A0A377DGX1|A0A377DGX1_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A1Q5ZEH3|A0A1Q5ZEH3_ECOLX/1-523 and tr|A0A3R8KSB7|A0A3R8KSB7_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0AAW5Z1M4|A0AAW5Z1M4_ECOLX/1-523 and tr|A0AAW6W494|A0AAW6W494_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|W1X2U4|W1X2U4_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0A376VQ42|A0A376VQ42_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|W1XNK9|W1XNK9_9ZZZZ/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0A6D1PLN0|A0A6D1PLN0_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0A8S7N1T2|A0A8S7N1T2_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|A0A0X5K2I6|A0A0X5K2I6_ECOLX/1-523 and tr|A0AAW5ZB89|A0AAW5ZB89_ECOLX/1-523 are exactly identical!
# WARNING: Sequences tr|W1YEN7|W1YEN7_9ZZZZ/1-523 and tr|A0A0H3PZQ4|A0A0H3PZQ4_ECO5C/1-523 are exactly identical!
# WARNING: Sequences tr|A0A767FIQ4|A0A767FIQ4_ECOLX/1-520 and tr|A0A793GC28|A0A793GC28_ECOLX/1-520 are exactly identical!
# WARNING: Sequences tr|A0A767FIQ4|A0A767FIQ4_ECOLX/1-520 and tr|A0A9P2PS47|A0A9P2PS47_ECOLX/1-520 are exactly identical!
# WARNING: Sequences tr|A0A767FIQ4|A0A767FIQ4_ECOLX/1-520 and tr|A0A9Q6ZFC8|A0A9Q6ZFC8_ECO57/1-520 are exactly identical!
# WARNING: Sequences tr|Q8XE85|Q8XE85_ECO57/1-518 and tr|A0A793GH32|A0A793GH32_ECOLX/1-518 are exactly identical!
# WARNING: Duplicate sequences found: 14
#
# NOTE: Reduced alignment (with duplicates and gap-only sites/taxa removed)
# NOTE: was saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs.raxml.reduced.phy
#
# Alignment comprises 1 partitions and 185 patterns
#
# Partition 0: noname
# Model: BLOSUM62+G4m
# Alignment sites / patterns: 524 / 185
# Gaps: 0.61 %
# Invariant sites: 71.37 %
#
#
# NOTE: Binary MSA file created: ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs.raxml.rba
#
# Parallelization scheme autoconfig: 8 worker(s) x 1 thread(s)
#
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 185 / 14800
# [00:00:00] Data distribution: max. searches per worker: 13
# [00:00:00] Starting bootstrapping analysis with 100 replicates.
#
# [00:00:08] [worker #5] Bootstrap tree #6, logLikelihood: -3009.051651
# [00:00:08] [worker #4] Bootstrap tree #5, logLikelihood: -3054.697583
# [00:00:08] [worker #3] Bootstrap tree #4, logLikelihood: -3041.283948
# [00:00:08] [worker #2] Bootstrap tree #3, logLikelihood: -3338.249156
# [00:00:10] [worker #7] Bootstrap tree #8, logLikelihood: -3124.308433
# [00:00:10] [worker #6] Bootstrap tree #7, logLikelihood: -3221.100242
# [00:00:11] [worker #1] Bootstrap tree #2, logLikelihood: -3219.219208
# [00:00:14] [worker #0] Bootstrap tree #1, logLikelihood: -2959.633179
# [00:00:15] [worker #5] Bootstrap tree #14, logLikelihood: -2996.507377
# [00:00:16] [worker #4] Bootstrap tree #13, logLikelihood: -3208.635777
# [00:00:16] [worker #3] Bootstrap tree #12, logLikelihood: -3346.843764
# [00:00:17] [worker #2] Bootstrap tree #11, logLikelihood: -3201.746497
# [00:00:18] [worker #7] Bootstrap tree #16, logLikelihood: -3224.810963
# [00:00:19] [worker #1] Bootstrap tree #10, logLikelihood: -3231.445439
# [00:00:22] [worker #6] Bootstrap tree #15, logLikelihood: -3211.840998
# [00:00:22] [worker #5] Bootstrap tree #22, logLikelihood: -2899.176371
# [00:00:23] [worker #0] Bootstrap tree #9, logLikelihood: -3309.868792
# [00:00:24] [worker #3] Bootstrap tree #20, logLikelihood: -3286.940873
# [00:00:26] [worker #1] Bootstrap tree #18, logLikelihood: -2996.311105
# [00:00:28] [worker #2] Bootstrap tree #19, logLikelihood: -2988.247049
# [00:00:29] [worker #7] Bootstrap tree #24, logLikelihood: -3294.822557
# [00:00:29] [worker #6] Bootstrap tree #23, logLikelihood: -3079.686348
# [00:00:30] [worker #5] Bootstrap tree #30, logLikelihood: -3226.798426
# [00:00:30] [worker #4] Bootstrap tree #21, logLikelihood: -3114.637139
# [00:00:31] [worker #0] Bootstrap tree #17, logLikelihood: -2932.593850
# [00:00:32] [worker #3] Bootstrap tree #28, logLikelihood: -3056.653806
# [00:00:34] [worker #1] Bootstrap tree #26, logLikelihood: -3243.812806
# [00:00:36] [worker #2] Bootstrap tree #27, logLikelihood: -3098.550095
# [00:00:38] [worker #6] Bootstrap tree #31, logLikelihood: -3259.644899
# [00:00:38] [worker #7] Bootstrap tree #32, logLikelihood: -3135.324215
# [00:00:39] [worker #0] Bootstrap tree #25, logLikelihood: -2960.023848
# [00:00:39] [worker #4] Bootstrap tree #29, logLikelihood: -3259.264359
# [00:00:40] [worker #3] Bootstrap tree #36, logLikelihood: -3378.425943
# [00:00:42] [worker #5] Bootstrap tree #38, logLikelihood: -3079.732957
# [00:00:42] [worker #1] Bootstrap tree #34, logLikelihood: -3046.752245
# [00:00:45] [worker #2] Bootstrap tree #35, logLikelihood: -3223.939719
# [00:00:45] [worker #6] Bootstrap tree #39, logLikelihood: -3094.453064
# [00:00:47] [worker #7] Bootstrap tree #40, logLikelihood: -3161.453137
# [00:00:48] [worker #0] Bootstrap tree #33, logLikelihood: -3274.128966
# [00:00:48] [worker #4] Bootstrap tree #37, logLikelihood: -3204.341699
# [00:00:49] [worker #3] Bootstrap tree #44, logLikelihood: -3221.939579
# [00:00:51] [worker #5] Bootstrap tree #46, logLikelihood: -2922.854704
# [00:00:52] [worker #1] Bootstrap tree #42, logLikelihood: -3087.513774
# [00:00:53] [worker #2] Bootstrap tree #43, logLikelihood: -3149.138002
# [00:00:54] [worker #6] Bootstrap tree #47, logLikelihood: -3066.537793
# [00:00:55] [worker #7] Bootstrap tree #48, logLikelihood: -3186.905220
# [00:00:56] [worker #4] Bootstrap tree #45, logLikelihood: -3048.769863
# [00:00:58] [worker #0] Bootstrap tree #41, logLikelihood: -3289.268284
# [00:01:00] [worker #1] Bootstrap tree #50, logLikelihood: -2995.547311
# [00:01:07] [worker #0] Bootstrap tree #49, logLikelihood: -3036.862984
# [00:01:14] [worker #6] Bootstrap tree #55, logLikelihood: -3108.178987
# [00:01:17] [worker #3] Bootstrap tree #52, logLikelihood: -3028.484382
# [00:01:17] [worker #5] Bootstrap tree #54, logLikelihood: -2995.041960
# [00:02:11] [worker #4] Bootstrap tree #85, logLikelihood: -2925.567356
# [00:02:13] [worker #5] Bootstrap tree #94, logLikelihood: -3012.605975
# [00:02:14] [worker #1] Bootstrap tree #98, logLikelihood: -3397.479872
# [00:02:14] [worker #3] Bootstrap tree #92, logLikelihood: -3120.885410
# [00:02:14] [worker #0] Bootstrap tree #97, logLikelihood: -3214.147637
# [00:02:16] [worker #7] Bootstrap tree #96, logLikelihood: -3257.885000
# [00:02:21] [worker #2] Bootstrap tree #99, logLikelihood: -3208.911174
# [00:02:24] [worker #4] Bootstrap tree #93, logLikelihood: -2954.238609
# [00:02:25] [worker #3] Bootstrap tree #100, logLikelihood: -3404.444450
#
# Bootstrap trees saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs.raxml.bootstraps
#
# Execution log saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs.raxml.log
#
# Analysis started: 02-Nov-2025 12:12:03 / finished: 02-Nov-2025 12:14:28
#
# Elapsed time: 145.752 seconds

# %%
# Map boostrap support onto ML tree

# Output: {PREFIX}_support.raxml.support -> final tree with bootstrap values
run(f"raxml-ng --support --tree {OUTDIR / (PREFIX + '.raxml.bestTree')} --bs-trees {OUTDIR / (PREFIX + '_bs.raxml.bootstraps')} --prefix {OUTDIR / (PREFIX + '_support')}")
# Out:
# $ raxml-ng --support --tree ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.bestTree --bs-trees ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs.raxml.bootstraps --prefix ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_support
#
#
# RAxML-NG v. 1.2.2 released on 30.04.2024 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth, Julia Haag, Anastasis Togkousidis.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M2, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 02-Nov-2025 12:15:43 as follows:
#
# raxml-ng --support --tree ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.bestTree --bs-trees ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs.raxml.bootstraps --prefix ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_support
#
# Analysis options:
#   run mode: Compute bipartition support (Felsenstein Bootstrap)
#   start tree(s): user
#   random seed: 1762085743
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# Reading reference tree from file: ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree.raxml.bestTree
# Reference tree size: 44
#
# Reading bootstrap trees from file: ../../data/cleaned/raxml/test/01_50id_bootstrap/mytree_bs.raxml.bootstraps
# Loaded 100 trees with 44 taxa.
#
# Best ML tree with Felsenstein bootstrap (FBP) support values saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree_support.raxml.support
#
# Execution log saved to: /Users/lachlanblack/Documents/GitHub/EspY3-protein-evolution/data/cleaned/raxml/test/01_50id_bootstrap/mytree_support.raxml.log
#
# Analysis started: 02-Nov-2025 12:15:43 / finished: 02-Nov-2025 12:15:43
#
# Elapsed time: 0.011 seconds

# %% [markdown]
# # Visualising the tree
#
# Open '{PREFIX}_support.raxml.support' in FigTree
# - Show Node Labels -> label to see boostrap support values (0-100)
# - The scale bar shows substitutions per site
# - You can midpoint-root or outgroup-root for directionality
