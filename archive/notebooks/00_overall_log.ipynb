# %% [markdown]
# # This notebook is for an overall log of my daily work
#
# ## October 30 (And prior)
#
# - Alligned uniprot 50% identity sequences with MAFFT
# - Trimmed sequences with trimAL
# - Created GitHub repository
# - Created notebooks for each step
#
# ## October 31
#
# - Allign pfam sequences with uniprot 50% identity
